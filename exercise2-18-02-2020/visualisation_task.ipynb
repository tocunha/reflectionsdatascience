# %%
import pandas as pd
import random
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Exercise–cholesterol study</h1>
#
# Researchers analised the data of 224 patients to investigate the relation between Exercise and cholesterol levels.

# %%
#Read the dataset
df = pd.read_csv('./dataset.csv')
df['Cholesterol'] = df['Cholesterol'] + 100
#Display the first 15 rows of the dataset
df.head(15)
# Out:
#      Exercise  Cholesterol  age_group  education gender
# 0   62.243439   170.608399         40          3      f
# 1   52.334988   114.705773         20          1      f
# 2   56.367947   146.395538         30          2      m
# 3   66.803946   166.174868         40          1      m
# 4   66.536051   189.246581         50          2      m
# 5   62.381286   191.452597         50          4      m
# 6   38.853831   106.763560         10          1      f
# 7   39.406283   163.062395         30          3      f
# 8   60.898191   192.562370         50          3      f
# 9   56.622926   145.757159         30          2      m
# 10  29.889250   106.580054         10          2      f
# 11  32.073863   114.153173         10          3      m
# 12  41.825185   155.482426         30          4      f
# 13  36.505409   110.158310         10          1      m
# 14  53.120758   144.302662         30          2      m

# %% [markdown]
# <h1>First the researchers visualised the data using a scatter plot</h1>

# %%
g = sns.scatterplot(x="Exercise", y="Cholesterol",data=df, s=70)

#set the limits of the plot
#plt.xlim(0,100)
#plt.ylim(0,120)

#set labels size
plt.xlabel('Exercise level', fontsize=18, fontweight='bold')
plt.ylabel('Cholesterol', fontsize=18, fontweight='bold')

#set ticks size
plt.xticks(fontsize=18)
t = plt.yticks(fontsize=18)

# %% [markdown]
# <h1>Then they ran a linear regression model and got to the conclusion that more exercise is associated to higher levels of cholesterol</h1>

# %%
#plot the data and fit a linear regression line
p = sns.lmplot(x="Exercise", y="Cholesterol",data=df)

#compute the correlation
corr = pearsonr(df['Exercise'],df['Cholesterol'])
plt.text(100, 200, "Correlation: {0:.2f}".format(corr[0]), fontsize= 18)

#set the limits of the plot
#plt.xlim(0,100)
#plt.ylim(0,120)

#set labels size
plt.xlabel('Exercise level', fontsize=18, fontweight='bold')
plt.ylabel('Cholesterol', fontsize=18, fontweight='bold')

#set ticks size
plt.xticks(fontsize=18)
t = plt.yticks(fontsize=18)

# %% [markdown]
# <h1>Your task as a data scientist is to analise this dataset and strategy and say if you agree or disagree with their findings and explain why.</h1>
